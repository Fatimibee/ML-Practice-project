# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Dataframe
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# is null or not

df.isnull().sum()     #0 means no null values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# now we are working on binary classification hence we remove one type of speceis

n_df = df[df['species'] != 'setosa']
print(n_df['species'].unique())
# Out:
# ['versicolor' 'virginica']

# %%
# now encode vesicolor =0 and virgnica = 1 b/c it doesnt deal with string
n_df['species']=n_df['species'].map({'versicolor':0,'virginica':1})
# Out:
# C:\Users\fatim\AppData\Local\Temp\ipykernel_12876\36504090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n_df['species']=n_df['species'].map({'versicolor':0,'virginica':1})

# %%
n_df.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 50           7.0          3.2           4.7          1.4        0
# 51           6.4          3.2           4.5          1.5        0
# 52           6.9          3.1           4.9          1.5        0
# 53           5.5          2.3           4.0          1.3        0
# 54           6.5          2.8           4.6          1.5        0

# %%
# now new dataset is ready with two type type of flower
X=n_df.iloc[:,:-1]
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 50            7.0          3.2           4.7          1.4
# 51            6.4          3.2           4.5          1.5
# 52            6.9          3.1           4.9          1.5
# 53            5.5          2.3           4.0          1.3
# 54            6.5          2.8           4.6          1.5
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [100 rows x 4 columns]

# %%
Y=n_df.iloc[:,-1]
Y
# Out:
# 50     0
# 51     0
# 52     0
# 53     0
# 54     0
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: species, Length: 100, dtype: int64

# %%
# training
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=45)

# %%
# now model apply
classification=LogisticRegression()

# %%
# now we need hypereparameter tunning
param_grid={
    'penalty':['l1', 'l2', 'elasticnet'],
    'C':[0.1,0.001,1,10,100],
    'max_iter':[3,4,5,6,7,20,30,100,500] 
}

# %%
from sklearn.model_selection import GridSearchCV

model=GridSearchCV(classification,param_grid,cv=5,scoring='accuracy')
model.fit(X_train,Y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(model.best_params_)
# Out:
# {'C': 0.1, 'max_iter': 7, 'penalty': 'l2'}

# %%
prediction=model.predict(X_test)

# %%
# now see accuracy
from sklearn.metrics import accuracy_score,classification_report

accuracy=accuracy_score(Y_test,prediction)
accuracy
# Out:
# 0.95

# %%
report=classification_report(prediction,Y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95         9
#            1       1.00      0.91      0.95        11
#
#     accuracy                           0.95        20
#    macro avg       0.95      0.95      0.95        20
# weighted avg       0.96      0.95      0.95        20

# %%
import joblib
joblib.dump(model,"iris_prediction.pkl")
# Out:
# ['iris_prediction.pkl']
